# %%
#READ THIS:!!!!!!!!
#Read Real Stock Testing TODO List.md for more information on what to do next.

import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# SETTINGS

tickers = input("Enter ticker symbols separated by commas (e.g., AAPL,MSFT): ").upper().split(',')
#User Input Start and End data taken away for testing purposes
start_date = "2020-01-01"
end_date = "2023-01-01"
#start_date = input("Enter the start date (YYYY-MM-DD): ")
#end_date = input("Enter the end date (YYYY-MM-DD): ")

#User Input for Moving Average Window Sizes taken away for testing purposes
short_window = 12
long_window = 26
#short_window = int(input("Enter the window size for short-term SMA/EMA: "))
#long_window = int(input("Enter the window size for long-term SMA/EMA: "))
use_ema_input = input("Use EMA instead of SMA? (True/False): ").strip().lower()
use_ema = (use_ema_input in ['true', 't', 'yes', 'y', 'e'])


#User Input for Starting Cash and Shares per Trade taken away for testing purposes
starting_cash = 100000
shares_per_trade = 100
#starting_cash = float(input("Enter starting capital (e.g., 100000): "))
#shares_per_trade = int(input("Enter number of shares per buy/sell (e.g., 100): "))

total_realized_profit = 0
ending_cash = starting_cash
all_results = []




def backtest_crossover(ticker):
    global total_realized_profit, ending_cash
   

    print(f"\nDownloading data for {ticker}...")
    data = yf.download(ticker, start=start_date, end=end_date)

    if data.empty:
        print(f"No data found for {ticker}. Skipping.\n")
        return

    prices = data['Close'].squeeze()

    # Calculate moving averages
    if use_ema:
        short_ma = prices.ewm(span=short_window).mean()
        long_ma = prices.ewm(span=long_window).mean()
    else:
        short_ma = prices.rolling(window=short_window).mean()
        long_ma = prices.rolling(window=long_window).mean()
    
    # Calculates RSI
    delta = prices.diff()
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    #User Input for RSI window size taken away for testing purposes
    rsiwindow = 14
    #rsiwindow = int(input("Enter the window size for RSI calculation (e.g., 14 STD): "))
    rsidelta = 100 - (100/(1+gain.ewm(alpha=1/rsiwindow, adjust=False).mean()/loss.ewm(alpha=1/rsiwindow,adjust=False).mean())) 
    

    # RSI overbought/oversold levels
    rsi_overbought = 65
    rsi_oversold = 35

    # Ask user if they want to use RSI filter
   #use_rsi_fliter = input("Use RSI filter for buy/sell signals? (True/False): ").strip().lower() == 'true'

    # Generate signals: Buy, Sell, Hold
    signals = ['Hold']
    for i in range(1, len(prices)):
        if short_ma.iloc[i] > long_ma.iloc[i] and short_ma.iloc[i-1] <= long_ma.iloc[i-1]:
            if rsidelta.iloc[i] < rsi_oversold: #or not use_rsi_fliter:  # Buy only if RSI indicates oversold
                signals.append('Strong Buy')
                print(f"ALERT: Strong Buy signal on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
            else:
                signals.append('Buy')

        elif short_ma.iloc[i] < long_ma.iloc[i] and short_ma.iloc[i-1] >= long_ma.iloc[i-1]:
            if rsidelta.iloc[i] > rsi_overbought: #or not use_rsi_fliter:  # Sell only if RSI indicates overbought
                signals.append('Strong Sell')
                print(f"ALERT: Strong Sell signal on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
            else:
                signals.append('Sell')
        else:
            signals.append('Hold')
    

    #Look back RSI check trading logic
    #User Input for Lookback period for RSI signal taken away for testing purposes
        #lookback = int(input("Enter lookback period for RSI signal (e.g., 5): "))

#Short-term: 2–3 periods — more sensitive, reacts faster, but more noise.
#Medium-term: 5–7 periods — smoother, avoids false signals from single-day spikes.
#Long-term: 10+ periods — very conservative, only catches strong moves.

    #Currently Lookback for RSI is in Days. Consider changing to minutes or Hours for more Day trading style
    Lookback = 5
    recent_rsi = rsidelta.iloc[max(0, i-Lookback):i+1]

    lookback_signals = ['Hold'] * len(prices)
    for i in range(Lookback, len(prices)):
        if recent_rsi.min() < rsi_oversold:
            print(f"Lookback ALERT: Recent RSI indicates oversold on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
            lookback_signals[i]='Buy Lookback RSI Confirmed'
        if recent_rsi.max() > rsi_overbought:
            print(f"Lookback ALERT: Recent RSI indicates overbought on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
            lookback_signals[i]='Sell Lookback RSI Confirmed'

    # Simulate trades
    position = 0
    cash = ending_cash
    portfolio_values = []
    buy_signals_dates = []
    buy_signals_prices = []
    sell_signals_dates = []
    sell_signals_prices = []
    buy_trades = 0
    sell_trades = 0
    profit = 0
    cost_basis = 0

    for i in range(len(prices)):
        price = prices.iloc[i]
        signal = signals[i]

        if signal == 'Buy' and position == 0:
            cost = price * shares_per_trade
            if cash >= cost:
                cash -= cost
                position = shares_per_trade
                cost_basis = price
                buy_trades += 1
                buy_signals_dates.append(prices.index[i])
                buy_signals_prices.append(price)
            else:
                # Not enough cash to buy
                signals[i] = 'Hold'

        elif signal == 'Sell' and position > 0:
            cash += price * position
            profit += (price - cost_basis) * position
            position = 0
            sell_trades += 1
            sell_signals_dates.append(prices.index[i])
            sell_signals_prices.append(price)

        # Track portfolio value each day
        portfolio_value = cash + position * price
        portfolio_values.append(portfolio_value)

    # Finalize if holding position at the end
    if position > 0:
        final_price = prices.iloc[-1]
        cash += final_price * position
        profit += (final_price - cost_basis) * position
        sell_signals_dates.append(prices.index[-1])
        sell_signals_prices.append(final_price)
        position = 0
        sell_trades += 1
        portfolio_values[-1] = cash
    total_realized_profit += profit
    ending_cash = cash

    roi_percent = (ending_cash - starting_cash) / starting_cash * 100

    all_results.append({
        'Ticker': ticker,
        'Buy Trades': buy_trades,
        'Sell Trades': sell_trades,
        'Ending Cash': cash,
        'Realized Profit': profit,
        'ROI (%)': roi_percent
    })

    # Plotting
    # Create subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 8), sharex=True)

    # --- Price and MAs ---
    ax1.plot(prices.index, prices, label='Price')
    ax1.plot(prices.index, short_ma, '--', label=f'Short {"EMA" if use_ema else "SMA"} ({short_window})')
    ax1.plot(prices.index, long_ma, '--', label=f'Long {"EMA" if use_ema else "SMA"} ({long_window})')
    ax1.scatter(buy_signals_dates, buy_signals_prices, marker='^', color='green', label='Buy Signal', s=100)
    ax1.scatter(sell_signals_dates, sell_signals_prices, marker='v', color='red', label='Sell Signal', s=100)
    ax1.set_title(f"{ticker} Crossover Strategy with Soft RSI Filter")
    ax1.set_ylabel("Price ($)")
    ax1.legend()
    ax1.grid(True)

    # --- RSI ---
    ax2.plot(prices.index, rsidelta, label= f'RSI ({rsiwindow})', color='purple')
    ax2.axhline(rsi_overbought, color='red', linestyle='--', label=f'Overbought ({rsi_overbought})')
    ax2.axhline(rsi_oversold, color='green', linestyle='--', label=f'Oversold ({rsi_oversold})')
    ax2.set_ylabel("RSI")
    ax2.set_ylim(0, 100)
    ax2.set_xlabel("Date")
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

    # Print trade summary for this ticker
    print(f"\nSummary of trades for {ticker}:")
    print(f"Buy Trades: {buy_trades}")
    print(f"Sell Trades: {sell_trades}")
    print(f"Ending Cash: ${cash:,.2f}")
    print(f"Realized Profit: ${profit:,.2f}")



# Run strategy for each ticker
for ticker in tickers:
    backtest_crossover(ticker)

# Final summary
results_df = pd.DataFrame(all_results)
print("\nAll strategies completed.")
print("\nFinal Summary for all tickers:")
print(results_df.to_string(index=False))
print(f"\nTotal Realized Profit Across All Tickers: ${total_realized_profit:,.2f}")
print(f"Ending Cash After All Trades: ${ending_cash:,.2f}")
print("Thank you for using Quantara!")
# Out:
# Downloading data for AAPL...
# C:\Users\logic\AppData\Local\Temp\ipykernel_22844\741566013.py:46: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-09 at price 74.78
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-10 at price 74.95
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-13 at price 76.55
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-14 at price 75.52
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-15 at price 75.19
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-16 at price 76.13
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-17 at price 76.98
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-21 at price 76.46
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-22 at price 76.73
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-23 at price 77.10
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-24 at price 76.88
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-27 at price 74.62
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-28 at price 76.73
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-29 at price 78.33
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-30 at price 78.22
# Lookback ALERT: Recent RSI indicates oversold on 2020-01-31 at price 74.75
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-03 at price 74.55
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-04 at price 77.01
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-05 at price 77.63
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-06 at price 78.54
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-07 at price 77.47
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-10 at price 77.84
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-11 at price 77.37
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-12 at price 79.21
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-13 at price 78.65
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-14 at price 78.67
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-18 at price 77.23
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-19 at price 78.34
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-20 at price 77.54
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-21 at price 75.79
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-24 at price 72.19
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-25 at price 69.74
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-26 at price 70.85
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-27 at price 66.22
# Lookback ALERT: Recent RSI indicates oversold on 2020-02-28 at price 66.18
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-02 at price 72.34
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-03 at price 70.04
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-04 at price 73.29
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-05 at price 70.91
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-06 at price 69.97
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-09 at price 64.44
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-10 at price 69.08
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-11 at price 66.68
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-12 at price 60.09
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-13 at price 67.29
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-16 at price 58.64
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-17 at price 61.21
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-18 at price 59.72
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-19 at price 59.26
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-20 at price 55.50
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-23 at price 54.32
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-24 at price 59.77
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-25 at price 59.44
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-26 at price 62.56
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-27 at price 59.97
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-30 at price 61.69
# Lookback ALERT: Recent RSI indicates oversold on 2020-03-31 at price 61.56
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-01 at price 58.32
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-02 at price 59.29
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-03 at price 58.44
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-06 at price 63.54
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-07 at price 62.80
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-08 at price 64.41
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-09 at price 64.88
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-13 at price 66.15
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-14 at price 69.49
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-15 at price 68.86
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-16 at price 69.40
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-17 at price 68.46
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-20 at price 67.04
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-21 at price 64.97
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-22 at price 66.84
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-23 at price 66.58
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-24 at price 68.50
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-27 at price 68.55
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-28 at price 67.44
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-29 at price 69.66
# Lookback ALERT: Recent RSI indicates oversold on 2020-04-30 at price 71.13
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-01 at price 69.98
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-04 at price 70.97
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-05 at price 72.04
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-06 at price 72.78
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-07 at price 73.53
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-08 at price 75.28
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-11 at price 76.47
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-12 at price 75.59
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-13 at price 74.68
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-14 at price 75.14
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-15 at price 74.69
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-18 at price 76.45
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-19 at price 76.01
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-20 at price 77.49
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-21 at price 76.91
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-22 at price 77.41
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-26 at price 76.88
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-27 at price 77.22
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-28 at price 77.25
# Lookback ALERT: Recent RSI indicates oversold on 2020-05-29 at price 77.18
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-01 at price 78.13
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-02 at price 78.49
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-03 at price 78.92
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-04 at price 78.24
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-05 at price 80.47
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-08 at price 80.94
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-09 at price 83.50
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-10 at price 85.65
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-11 at price 81.54
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-12 at price 82.24
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-15 at price 83.26
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-16 at price 85.46
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-17 at price 85.35
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-18 at price 85.38
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-19 at price 84.89
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-22 at price 87.11
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-23 at price 88.97
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-24 at price 87.40
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-25 at price 88.56
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-26 at price 85.84
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-29 at price 87.82
# Lookback ALERT: Recent RSI indicates oversold on 2020-06-30 at price 88.55
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-01 at price 88.38
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-02 at price 88.38
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-06 at price 90.75
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-07 at price 90.47
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-08 at price 92.57
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-09 at price 92.97
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-10 at price 93.14
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-13 at price 92.71
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-14 at price 94.24
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-15 at price 94.89
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-16 at price 93.72
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-17 at price 93.53
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-20 at price 95.50
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-21 at price 94.18
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-22 at price 94.45
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-23 at price 90.15
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-24 at price 89.93
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-27 at price 92.06
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-28 at price 90.55
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-29 at price 92.28
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-30 at price 93.40
# Lookback ALERT: Recent RSI indicates oversold on 2020-07-31 at price 103.17
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-03 at price 105.77
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-04 at price 106.48
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-05 at price 106.87
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-06 at price 110.60
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-07 at price 108.08
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-10 at price 109.65
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-11 at price 106.39
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-12 at price 109.93
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-13 at price 111.87
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-14 at price 111.77
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-17 at price 111.48
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-18 at price 112.41
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-19 at price 112.55
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-20 at price 115.05
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-21 at price 120.98
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-24 at price 122.42
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-25 at price 121.42
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-26 at price 123.07
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-27 at price 121.60
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-28 at price 121.40
# Lookback ALERT: Recent RSI indicates oversold on 2020-08-31 at price 125.52
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-01 at price 130.52
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-02 at price 127.82
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-03 at price 117.58
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-04 at price 117.66
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-08 at price 109.74
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-09 at price 114.12
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-10 at price 110.39
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-11 at price 108.94
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-14 at price 112.21
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-15 at price 112.39
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-16 at price 109.07
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-17 at price 107.33
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-18 at price 103.93
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-21 at price 107.08
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-22 at price 108.76
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-23 at price 104.20
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-24 at price 105.27
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-25 at price 109.22
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-28 at price 111.82
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-29 at price 110.98
# Lookback ALERT: Recent RSI indicates oversold on 2020-09-30 at price 112.65
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-01 at price 113.60
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-02 at price 109.94
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-05 at price 113.32
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-06 at price 110.07
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-07 at price 111.94
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-08 at price 111.83
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-09 at price 113.78
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-12 at price 121.01
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-13 at price 117.80
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-14 at price 117.88
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-15 at price 117.42
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-16 at price 115.77
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-19 at price 112.82
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-20 at price 114.30
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-21 at price 113.68
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-22 at price 112.59
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-23 at price 111.90
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-26 at price 111.91
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-27 at price 113.42
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-28 at price 108.17
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-29 at price 112.17
# Lookback ALERT: Recent RSI indicates oversold on 2020-10-30 at price 105.89
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-02 at price 105.80
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-03 at price 107.43
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-04 at price 111.81
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-05 at price 115.78
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-06 at price 115.65
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-09 at price 113.34
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-10 at price 113.00
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-11 at price 116.43
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-12 at price 116.16
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-13 at price 116.21
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-16 at price 117.22
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-17 at price 116.33
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-18 at price 115.01
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-19 at price 115.60
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-20 at price 114.34
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-23 at price 110.93
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-24 at price 112.22
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-25 at price 113.06
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-27 at price 113.60
# Lookback ALERT: Recent RSI indicates oversold on 2020-11-30 at price 116.00
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-01 at price 119.58
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-02 at price 119.93
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-03 at price 119.79
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-04 at price 119.12
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-07 at price 120.58
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-08 at price 121.20
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-09 at price 118.66
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-10 at price 120.08
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-11 at price 119.28
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-14 at price 118.66
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-15 at price 124.61
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-16 at price 124.54
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-17 at price 125.40
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-18 at price 123.42
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-21 at price 124.95
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-22 at price 128.50
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-23 at price 127.61
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-24 at price 128.59
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-28 at price 133.19
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-29 at price 131.42
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-30 at price 130.30
# Lookback ALERT: Recent RSI indicates oversold on 2020-12-31 at price 129.29
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-04 at price 126.10
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-05 at price 127.66
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-06 at price 123.36
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-07 at price 127.57
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-08 at price 128.67
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-11 at price 125.68
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-12 at price 125.50
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-13 at price 127.54
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-14 at price 125.61
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-15 at price 123.88
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-19 at price 124.56
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-20 at price 128.65
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-21 at price 133.37
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-22 at price 135.51
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-25 at price 139.26
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-26 at price 139.49
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-27 at price 138.42
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-28 at price 133.58
# Lookback ALERT: Recent RSI indicates oversold on 2021-01-29 at price 128.58
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-01 at price 130.71
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-02 at price 131.53
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-03 at price 130.51
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-04 at price 133.87
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-05 at price 133.46
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-08 at price 133.60
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-09 at price 132.73
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-10 at price 132.12
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-11 at price 131.87
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-12 at price 132.10
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-16 at price 129.97
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-17 at price 127.68
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-18 at price 126.58
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-19 at price 126.73
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-22 at price 122.96
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-23 at price 122.82
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-24 at price 122.32
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-25 at price 118.07
# Lookback ALERT: Recent RSI indicates oversold on 2021-02-26 at price 118.33
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-01 at price 124.70
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-02 at price 122.10
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-03 at price 119.11
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-04 at price 117.23
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-05 at price 118.49
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-08 at price 113.55
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-09 at price 118.17
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-10 at price 117.08
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-11 at price 119.01
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-12 at price 118.11
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-15 at price 121.00
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-16 at price 122.54
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-17 at price 121.75
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-18 at price 117.62
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-19 at price 117.09
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-22 at price 120.41
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-23 at price 119.58
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-24 at price 117.19
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-25 at price 117.68
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-26 at price 118.28
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-29 at price 118.46
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-30 at price 117.00
# Lookback ALERT: Recent RSI indicates oversold on 2021-03-31 at price 119.20
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-01 at price 120.03
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-05 at price 122.86
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-06 at price 123.16
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-07 at price 124.81
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-08 at price 127.21
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-09 at price 129.79
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-12 at price 128.07
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-13 at price 131.18
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-14 at price 128.84
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-15 at price 131.25
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-16 at price 130.92
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-19 at price 131.58
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-20 at price 129.90
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-21 at price 130.28
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-22 at price 128.75
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-23 at price 131.08
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-26 at price 131.47
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-27 at price 131.14
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-28 at price 130.35
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-29 at price 130.26
# Lookback ALERT: Recent RSI indicates oversold on 2021-04-30 at price 128.29
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-03 at price 129.34
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-04 at price 124.76
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-05 at price 125.01
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-06 at price 126.61
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-07 at price 127.28
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-10 at price 124.00
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-11 at price 123.08
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-12 at price 120.01
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-13 at price 122.16
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-14 at price 124.58
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-17 at price 123.43
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-18 at price 122.04
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-19 at price 121.89
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-20 at price 124.45
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-21 at price 122.61
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-24 at price 124.24
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-25 at price 124.05
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-26 at price 124.00
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-27 at price 122.46
# Lookback ALERT: Recent RSI indicates oversold on 2021-05-28 at price 121.81
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-01 at price 121.48
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-02 at price 122.25
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-03 at price 120.76
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-04 at price 123.06
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-07 at price 123.07
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-08 at price 123.89
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-09 at price 124.27
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-10 at price 123.27
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-11 at price 124.49
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-14 at price 127.55
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-15 at price 126.72
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-16 at price 127.22
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-17 at price 128.83
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-18 at price 127.53
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-21 at price 129.32
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-22 at price 130.97
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-23 at price 130.69
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-24 at price 130.41
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-25 at price 130.12
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-28 at price 131.75
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-29 at price 133.26
# Lookback ALERT: Recent RSI indicates oversold on 2021-06-30 at price 133.88
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-01 at price 134.18
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-02 at price 136.81
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-06 at price 138.83
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-07 at price 141.32
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-08 at price 140.02
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-09 at price 141.85
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-12 at price 141.25
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-13 at price 142.36
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-14 at price 145.80
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-15 at price 145.14
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-16 at price 143.10
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-19 at price 139.25
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-20 at price 142.86
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-21 at price 142.13
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-22 at price 143.50
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-23 at price 145.22
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-26 at price 145.64
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-27 at price 143.47
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-28 at price 141.72
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-29 at price 142.36
# Lookback ALERT: Recent RSI indicates oversold on 2021-07-30 at price 142.58
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-02 at price 142.25
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-03 at price 144.05
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-04 at price 143.65
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-05 at price 143.75
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-06 at price 143.07
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-09 at price 143.02
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-10 at price 142.54
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-11 at price 142.79
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-12 at price 145.76
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-13 at price 145.97
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-16 at price 147.94
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-17 at price 147.03
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-18 at price 143.28
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-19 at price 143.62
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-20 at price 145.07
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-23 at price 146.56
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-24 at price 146.47
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-25 at price 145.24
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-26 at price 144.44
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-27 at price 145.48
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-30 at price 149.90
# Lookback ALERT: Recent RSI indicates oversold on 2021-08-31 at price 148.64
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-01 at price 149.30
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-02 at price 150.42
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-03 at price 151.06
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-07 at price 153.40
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-08 at price 151.85
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-09 at price 150.83
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-10 at price 145.84
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-13 at price 146.41
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-14 at price 145.01
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-15 at price 145.90
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-16 at price 145.66
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-17 at price 142.99
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-20 at price 139.93
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-21 at price 140.41
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-22 at price 142.78
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-23 at price 143.74
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-24 at price 143.83
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-27 at price 142.31
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-28 at price 138.93
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-29 at price 139.83
# Lookback ALERT: Recent RSI indicates oversold on 2021-09-30 at price 138.52
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-01 at price 139.65
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-04 at price 136.21
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-05 at price 138.14
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-06 at price 139.01
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-07 at price 140.28
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-08 at price 139.90
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-11 at price 139.81
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-12 at price 138.53
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-13 at price 137.95
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-14 at price 140.74
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-15 at price 141.79
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-18 at price 143.47
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-19 at price 145.63
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-20 at price 146.12
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-21 at price 146.34
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-22 at price 145.56
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-25 at price 145.51
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-26 at price 146.18
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-27 at price 145.72
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-28 at price 149.36
# Lookback ALERT: Recent RSI indicates oversold on 2021-10-29 at price 146.65
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-01 at price 145.83
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-02 at price 146.87
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-03 at price 148.30
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-04 at price 147.79
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-05 at price 148.32
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-08 at price 147.49
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-09 at price 147.85
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-10 at price 145.02
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-11 at price 144.97
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-12 at price 147.05
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-15 at price 147.06
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-16 at price 148.04
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-17 at price 150.48
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-18 at price 154.78
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-19 at price 157.40
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-22 at price 157.86
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-23 at price 158.25
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-24 at price 158.77
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-26 at price 153.74
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-29 at price 157.10
# Lookback ALERT: Recent RSI indicates oversold on 2021-11-30 at price 162.06
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-01 at price 161.54
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-02 at price 160.55
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-03 at price 158.67
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-06 at price 162.08
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-07 at price 167.83
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-08 at price 171.65
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-09 at price 171.14
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-10 at price 175.93
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-13 at price 172.30
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-14 at price 170.91
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-15 at price 175.79
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-16 at price 168.88
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-17 at price 167.79
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-20 at price 166.42
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-21 at price 169.60
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-22 at price 172.20
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-23 at price 172.83
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-27 at price 176.80
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-28 at price 175.78
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-29 at price 175.86
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-30 at price 174.71
# Lookback ALERT: Recent RSI indicates oversold on 2021-12-31 at price 174.09
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-03 at price 178.44
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-04 at price 176.18
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-05 at price 171.49
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-06 at price 168.63
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-07 at price 168.80
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-10 at price 168.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-11 at price 171.65
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-12 at price 172.09
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-13 at price 168.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-14 at price 169.68
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-18 at price 166.47
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-19 at price 162.97
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-20 at price 161.29
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-21 at price 159.23
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-24 at price 158.45
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-25 at price 156.65
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-26 at price 156.56
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-27 at price 156.10
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-28 at price 166.99
# Lookback ALERT: Recent RSI indicates oversold on 2022-01-31 at price 171.35
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-01 at price 171.19
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-02 at price 172.39
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-03 at price 169.51
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-04 at price 169.23
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-07 at price 168.51
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-08 at price 171.62
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-09 at price 173.05
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-10 at price 168.96
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-11 at price 165.55
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-14 at price 165.78
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-15 at price 169.62
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-16 at price 169.38
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-17 at price 165.78
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-18 at price 164.23
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-22 at price 161.31
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-23 at price 157.13
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-24 at price 159.75
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-25 at price 161.83
# Lookback ALERT: Recent RSI indicates oversold on 2022-02-28 at price 162.09
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-01 at price 160.21
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-02 at price 163.50
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-03 at price 163.18
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-04 at price 160.18
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-07 at price 156.38
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-08 at price 154.55
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-09 at price 159.96
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-10 at price 155.61
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-11 at price 151.89
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-14 at price 147.86
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-15 at price 152.24
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-16 at price 156.66
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-17 at price 157.67
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-18 at price 160.97
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-21 at price 162.35
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-22 at price 165.72
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-23 at price 167.09
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-24 at price 170.88
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-25 at price 171.51
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-28 at price 172.38
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-29 at price 175.68
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-30 at price 174.51
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-31 at price 171.41
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-01 at price 171.11
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-04 at price 175.17
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-05 at price 171.85
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-06 at price 168.68
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-07 at price 168.98
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-08 at price 166.97
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-11 at price 162.71
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-12 at price 164.58
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-13 at price 167.27
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-14 at price 162.26
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-18 at price 162.04
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-19 at price 164.33
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-20 at price 164.16
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-21 at price 163.37
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-22 at price 158.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-25 at price 159.89
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-26 at price 153.92
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-27 at price 153.70
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-28 at price 160.64
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-29 at price 154.76
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-02 at price 155.06
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-03 at price 156.55
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-04 at price 162.97
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-05 at price 153.89
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-06 at price 154.62
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-09 at price 149.49
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-10 at price 151.90
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-11 at price 144.02
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-12 at price 140.15
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-13 at price 144.62
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-16 at price 143.08
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-17 at price 146.72
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-18 at price 138.44
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-19 at price 135.03
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-20 at price 135.26
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-23 at price 140.69
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-24 at price 137.99
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-25 at price 138.14
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-26 at price 141.35
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-27 at price 147.11
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-31 at price 146.32
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-01 at price 146.20
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-02 at price 148.65
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-03 at price 142.92
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-06 at price 143.67
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-07 at price 146.20
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-08 at price 145.46
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-09 at price 140.23
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-10 at price 134.81
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-13 at price 129.65
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-14 at price 130.52
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-15 at price 133.14
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-16 at price 127.86
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-17 at price 129.34
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-21 at price 133.57
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-22 at price 133.06
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-23 at price 135.93
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-24 at price 139.27
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-27 at price 139.27
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-28 at price 135.12
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-29 at price 136.88
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-30 at price 134.41
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-01 at price 136.58
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-05 at price 139.17
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-06 at price 140.50
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-07 at price 143.88
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-08 at price 144.55
# ...
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-15 at price 267.30
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-16 at price 280.08
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-17 at price 290.53
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-18 at price 301.80
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-21 at price 307.05
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-22 at price 331.33
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-23 at price 333.04
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-24 at price 337.97
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-25 at price 336.88
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-28 at price 363.95
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-29 at price 366.52
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-30 at price 364.66
# Lookback ALERT: Recent RSI indicates oversold on 2022-03-31 at price 359.20
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-01 at price 361.53
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-04 at price 381.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-05 at price 363.75
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-06 at price 348.59
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-07 at price 352.42
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-08 at price 341.83
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-11 at price 325.31
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-12 at price 328.98
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-13 at price 340.79
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-14 at price 328.33
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-18 at price 334.76
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-19 at price 342.72
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-20 at price 325.73
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-21 at price 336.26
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-22 at price 335.02
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-25 at price 332.67
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-26 at price 292.14
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-27 at price 293.84
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-28 at price 292.50
# Lookback ALERT: Recent RSI indicates oversold on 2022-04-29 at price 290.25
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-02 at price 300.98
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-03 at price 303.08
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-04 at price 317.54
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-05 at price 291.09
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-06 at price 288.55
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-09 at price 262.37
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-10 at price 266.68
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-11 at price 244.67
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-12 at price 242.67
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-13 at price 256.53
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-16 at price 241.46
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-17 at price 253.87
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-18 at price 236.60
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-19 at price 236.47
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-20 at price 221.30
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-23 at price 224.97
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-24 at price 209.39
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-25 at price 219.60
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-26 at price 235.91
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-27 at price 253.21
# Lookback ALERT: Recent RSI indicates oversold on 2022-05-31 at price 252.75
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-01 at price 246.79
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-02 at price 258.33
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-03 at price 234.52
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-06 at price 238.28
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-07 at price 238.89
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-08 at price 241.87
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-09 at price 239.71
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-10 at price 232.23
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-13 at price 215.74
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-14 at price 220.89
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-15 at price 233.00
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-16 at price 213.10
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-17 at price 216.76
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-21 at price 237.04
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-22 at price 236.09
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-23 at price 235.07
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-24 at price 245.71
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-27 at price 244.92
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-28 at price 232.66
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-29 at price 228.49
# Lookback ALERT: Recent RSI indicates oversold on 2022-06-30 at price 224.47
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-01 at price 227.26
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-05 at price 233.07
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-06 at price 231.73
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-07 at price 244.54
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-08 at price 250.76
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-11 at price 234.34
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-12 at price 233.07
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-13 at price 237.04
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-14 at price 238.31
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-15 at price 240.07
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-18 at price 240.55
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-19 at price 245.53
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-20 at price 247.50
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-21 at price 271.71
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-22 at price 272.24
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-25 at price 268.43
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-26 at price 258.86
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-27 at price 274.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-28 at price 280.90
# Lookback ALERT: Recent RSI indicates oversold on 2022-07-29 at price 297.15
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-01 at price 297.28
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-02 at price 300.59
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-03 at price 307.40
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-04 at price 308.63
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-05 at price 288.17
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-08 at price 290.42
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-09 at price 283.33
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-10 at price 294.36
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-11 at price 286.63
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-12 at price 300.03
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-15 at price 309.32
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-16 at price 306.56
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-17 at price 304.00
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-18 at price 302.87
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-19 at price 296.67
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-22 at price 289.91
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-23 at price 296.45
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-24 at price 297.10
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-25 at price 296.07
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-26 at price 288.09
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-29 at price 284.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-30 at price 277.70
# Lookback ALERT: Recent RSI indicates oversold on 2022-08-31 at price 275.61
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-01 at price 277.16
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-02 at price 270.21
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-06 at price 274.42
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-07 at price 283.70
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-08 at price 289.26
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-09 at price 299.68
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-12 at price 304.42
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-13 at price 292.13
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-14 at price 302.61
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-15 at price 303.75
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-16 at price 303.35
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-19 at price 309.07
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-20 at price 308.73
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-21 at price 300.80
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-22 at price 288.59
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-23 at price 275.33
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-26 at price 276.01
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-27 at price 282.94
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-28 at price 287.81
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-29 at price 268.21
# Lookback ALERT: Recent RSI indicates oversold on 2022-09-30 at price 265.25
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-03 at price 242.40
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-04 at price 249.44
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-05 at price 240.81
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-06 at price 238.13
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-07 at price 223.07
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-10 at price 222.96
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-11 at price 216.50
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-12 at price 217.24
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-13 at price 221.72
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-14 at price 204.99
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-17 at price 219.35
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-18 at price 220.19
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-19 at price 222.04
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-20 at price 207.28
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-21 at price 214.44
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-24 at price 211.25
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-25 at price 222.42
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-26 at price 224.64
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-27 at price 225.09
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-28 at price 228.52
# Lookback ALERT: Recent RSI indicates oversold on 2022-10-31 at price 227.54
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-01 at price 227.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-02 at price 214.98
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-03 at price 215.31
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-04 at price 207.47
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-07 at price 197.08
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-08 at price 191.30
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-09 at price 177.59
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-10 at price 190.72
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-11 at price 195.97
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-14 at price 190.95
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-15 at price 194.42
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-16 at price 186.92
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-17 at price 183.17
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-18 at price 180.19
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-21 at price 167.87
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-22 at price 169.91
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-23 at price 183.20
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-25 at price 182.86
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-28 at price 182.92
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-29 at price 180.83
# Lookback ALERT: Recent RSI indicates oversold on 2022-11-30 at price 194.70
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-01 at price 194.70
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-02 at price 194.86
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-05 at price 182.45
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-06 at price 179.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-07 at price 174.04
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-08 at price 173.44
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-09 at price 179.05
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-12 at price 167.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-13 at price 160.95
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-14 at price 156.80
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-15 at price 157.67
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-16 at price 150.23
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-19 at price 149.87
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-20 at price 137.80
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-21 at price 137.57
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-22 at price 125.35
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-23 at price 123.15
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-27 at price 109.10
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-28 at price 112.71
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-29 at price 121.82
# Lookback ALERT: Recent RSI indicates oversold on 2022-12-30 at price 123.18
# Summary of trades for TSLA:
# Buy Trades: 10
# Sell Trades: 10
# Ending Cash: $124,042.98
# Realized Profit: $19,580.67
#
# All strategies completed.
#
# Final Summary for all tickers:
# Ticker  Buy Trades  Sell Trades   Ending Cash  Realized Profit   ROI (%)
#   AAPL          12           12 104215.359497      4215.359497  4.215359
#   NVDA          15           15 104462.304211       246.944714  4.462304
#   TSLA          10           10 124042.976665     19580.672455 24.042977
#
# Total Realized Profit Across All Tickers: $24,042.98
# Ending Cash After All Trades: $124,042.98
# Thank you for using TradeVision!
